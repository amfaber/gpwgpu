# %%
output
# Out:
# array([288.81943], dtype=float32)

# %%
this_temp = inp.copy()
to_start = len(inp)
fold = 4
to_start += (fold - 1)
to_start //= fold
for it in range(4):
    for i in range(to_start):
        for j in range(1, fold):
            # if i + j * to_start < len(this_temp):
            this_temp[i] += this_temp[i + j * to_start]
    # this_temp = this_temp[:to_start]
    to_start += (fold - 1)
    to_start //= fold
this_temp
# Out:
# array([127872., 125878., 126131., 121872.,  31840.,  31904.,  31968.,
#         32032.,  32096.,  32160.,  32224.,  32288.,  32352.,  30166.,
#         30227.,  25776.,   7768.,   7784.,   7800.,   7816.,   7832.,
#          7848.,   7864.,   7880.,   7896.,   7912.,   7928.,   7944.,
#          7960.,   7976.,   7992.,   8008.,   8024.,   8040.,   8056.,
#          8072.,   8088.,   8104.,   8120.,   8136.,   8152.,   8168.,
#          8184.,   8200.,   8216.,   8232.,   8248.,   8264.,   8280.,
#          8296.,   8312.,   8328.,   8344.,   8360.,   8376.,   8392.,
#          8408.,   8424.,   8440.,   8456.,   8472.,   6238.,   6251.,
#          1752.,   1756.,   1760.,   1764.,   1768.,   1772.,   1776.,
#          1780.,   1784.,   1788.,   1792.,   1796.,   1800.,   1804.,
#          1808.,   1812.,   1816.,   1820.,   1824.,   1828.,   1832.,
#          1836.,   1840.,   1844.,   1848.,   1852.,   1856.,   1860.,
# ...
